# %% [markdown]
# # Лекция 01. Основы Python

# %% [markdown]
# ### Про выполнение команд
# * Shift + Enter - выполнить код в ячейке и перейти на следующую
# * Ctrl + Enter - выполнить и остаться
#
# ### Немного полезностей и про markdown:
# * перевести ячейку из кода в комментарии можно с помощью 'Esc + m' или просто 'm', если вы не еще не успели сделать ее активной
# * для перевода наоборот в ячейку кода 'y'
# * добавить новую ячейку можно аналогичным образом через 'b'
# * Jupyter понимает эти команды и в русской раскладке
# * все это можно сделать и через верхнюю панель, но это дольше
# * список горячих клавиш Ctrl+Shift+P (Command+Shift+P для мака)

# %% [markdown]
# ## Оглавление:
# * [01.01. Арифметические операции](#1)
# * [01.02. Переменные](#2)
# * [01.03. Строки](#3)
# * [01.04. Операторы сравнения](#4)
# * [01.05. Условные конструкции](#5)
# * [01.06. Логические операторы and и or](#6)
# * [Упражнения на уроке](#7)
# * [Домашнее задание](#8)

# %% [markdown]
# ## 01.01. Арифметические операции <a class="anchor" id="1"></a>
# Приоритет операции аналогичен стандартным математическим правилам, можно использовать скобки.

# %%
print(1 + 1) # Простое суммирование
# Out:
# 2

# %%
print(2 - 1, 5 + 6) # Простое сложение и вычитание
# Out:
# 1 11

# %%
# для вывода в jupyter notebook не обязательно использовать print
1 + 1
# Out:
# 2

# %%
1 + 1
2 - 1 # выводит последнюю
# Out:
# 1

# %%
print(1 + 1)
print(2 - 1)
# Out:
# 2
# 1

# %%
5 * 6 # Простое умножение
# Out:
# 30

# %%
10 / 4 # Простое деление
# Out:
# 2.5

# %%
10 // 4 # Целочисленное деление
# Out:
# 2

# %%
2 ** 5 # Возведение в степень
# Out:
# 32

# %%
10 % 3 # Взятие остатка от деления
# Out:
# 1

# %%
(5 - 3) + 2 * 6 # Простые вычисления
# Out:
# 14

# %% [markdown]
# ## 01.02. Переменные <a class="anchor" id="2"></a>
# Переменная – это объект, которому дано имя. Необходимы, в том числе, для хранения данных и промежуточных результатов вычислений.

# %% [markdown]
# ###### Правила именования (необязательно, но лучше так):
# * Имя переменной может состоять только из цифр, букв и знаков подчеркивания.
# * Имя переменной не может начинаться с цифры.
#
# ###### Рекомендации именования:
# * Имя переменной должно описывать ее суть;
# * Лучше использовать **snake_case** (слова писать с маленькой буквы и разделять нижним подчеркиванием).

# %%
a = 10 + 20
b = a * 30
c = a / b
print('Ответ: ', c)
# Out:
# Ответ:  0.03333333333333333

# %%
# Нужно сначала задать переменную
print(x)

x = 10
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-8dbc90be4e05> in <module>()
#       1 # Нужно сначала задать переменную
# ----> 2 print(x)
#       3
#       4 x = 10
#
# NameError: name 'x' is not defined

# %% [markdown]
# ## 01.03. Строки <a class="anchor" id="3"></a>

# %%
my_string_1 = 'Hello World!'

# %%
my_string_2 = "Hello World!"

# %% [markdown]
# Метод **.format**

# %%
age = 26 # Числовое значение
name = 'Swaroop'
print('Возраст {0} -- {1} лет.'.format(name, age)) # Позволяет перевести любое значение в строку и вставить его в нужное место.
print('Почему {0} забавляется с этим Python?'.format(name))
# Out:
# Возраст Swaroop -- 26 лет.
# Почему Swaroop забавляется с этим Python?

# %% [markdown]
# ## 01.04. Операторы сравнения <a class="anchor" id="4"></a>

# %%
2 > 1 # больше
# Out:
# True

# %%
10 < 9 # меньше
# Out:
# False

# %%
10 > 10 # больше
# Out:
# False

# %%
10 >= 10 # больше или равно
# Out:
# True

# %%
7 == 7 # равно (= - зарезервирован для присвоения)
# Out:
# True

# %%
15 != 15 # не равно
# Out:
# False

# %%
5 > 4 < 10 # можно записывать в цепочку
# Out:
# True

# %%
# сравнение строк. Лексиграфическое сравнение: присваивается вес, чем дальше от начала, тем больше
print('c' > 'a')
# Out:
# True

# %%
print('b' > 'B') # сначала верхний регистр, потом нижний
# Out:
# True

# %%
print('abc' > 'aba') # тексты сравниваются посимвольно
# Out:
# True

# %%
len('abc') > len('dfhjdfj') # сравнивается длина строки (кол-во символов в строке)
# Out:
# False

# %% [markdown]
# ## 01.05. Условные конструкции <a class="anchor" id="5"></a>
# <img src="attachment:image.png" width="500">

# %%
x = 7
if x % 2 == 0:
    print(x, '- четное число')

# %%
if x % 2 == 0:
    print(x, '- четное число')
else:
    print(x, '- нечетное число')
# Out:
# 7 - нечетное число

# %%
# Пишем программу для определения куда направить призывника
height = 182
if height < 170:
    print('В танкисты')

print('Конец программы')
# Out:
# Конец программы

# %%
if height < 170:
    print('В танкисты')
else:
    print('В другие войска')
print('Конец программы')
# Out:
# В другие войска
# Конец программы

# %%
# условия выполняются по порядку, как только одно выполнено - проверки останавливаются
if height < 170:
    print('В танкисты')
elif height < 200:
    print('В десантники')
else:
    print('В другие войска')
print('Конец программы')
# Out:
# В десантники
# Конец программы

# %%
# блоков elif может быть хоть сколько
if height < 170:
    print('В танкисты')
elif height < 185:
    print('На флот')
elif height < 200:
    print('В десантники')
else:
    print('В другие войска')
print('Конец программы')
# Out:
# На флот
# Конец программы

# %% [markdown]
# ## 01.06. Логические операторы and и or <a class="anchor" id="6"></a>

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
True or False
# Out:
# True

# %%
not True
# Out:
# False

# %%
((9 > 7) and (2 < 4))  # ((True) and (True))
# Out:
# True

# %%
(8 == 8) or (6 != 6)
# Out:
# True

# %%
not(3 <= 1)
# Out:
# True

# %%
age = 21
height = 180
if height < 170 and age >= 18:
    print('В танкисты')
elif height < 185 and age >= 18:
    print('На флот')
elif height < 185 and age >= 18:
    print('В десантники')
else:
    print('В другие войска')
print('Конец программы')
# Out:
# На флот
# Конец программы

# %%
if age >= 18:
    height = int(input('Введите рост'))
    if height < 170:
        print('В танкисты')
    elif height < 185:
        print('На флот')
    elif height < 185:
        print('В десантники')
    else:
        print('В другие войска')
else:
    print('Непризывной возраст')
print('Конец программы')
# Out:
# Введите рост150
# В танкисты
# Конец программы

# %%
# Логические выражения: опове
account_amount = 1000
loan_amount = 1500
days_to_pay = 6
is_holiday = True

should_notify = account_amount < loan_amount and \
    ((days_to_pay < 10 and not is_holiday) or (days_to_pay == 15))
should_notify
# Out:
# False

# %%
# функция input принимает пользовательский ввод
name = input('Введите имя')

if name:     # пустая строка вернет False. Зачем все это? Не писать, что if name != ''
    print('Привет, ', name)
else:
    print('Привет, Мир!')
# Out:
# Введите имяjl;
# Привет,  jl;

# %%
number = input('Введите число')

if number:    # 0 вернет False
    print('Число: ', number)
else:
    print('Число равно нулю')
# Out:
# Введите число23
# Число:  23

# %% [markdown]
# ## Упражнение на уроке.  <a class="anchor" id="7"></a>
# Необходим скрипт для подбора упаковок по размерам товара. Используйте следующие правила:
# - если ширина, длина и высота менее 15 сантиметров, то выведите на экран "Коробка №1"
# - если хотя бы один из габаритов больше 15см, но менее 50см, то выводите "Коробка №2"
# - если длина товара больше 2 метров, то вывести "ищите упаковку для лыж"
# - во всех остальных случаях пишите "Стандартная коробка №3"

# %%
width = 45
length = 190
height = 15

# %%
if width < 15 or length < 15 or height < 15:
    print('Коробка №1')    
elif length > 200:     
    print('ищите упаковку для лыж')    
elif 15 < width < 50 or 15 < length < 50 or 15 < height < 50: 
    print('Коробка №2')
else:
    print('Стандартная коробка №3')
# Out:
# Коробка №2

# %% [markdown]
# ## Домашние задания <a class="anchor" id="8"></a>

# %% [markdown]
# **Задание 1**. Даны 2 строки: *long_phrase* и *short_phrase*.
# Напишите код, который проверяет действительно ли длинная фраза *long_phrase* длиннее короткой *short_phrase*. И выводит *True* или *False* в зависимости от результата сравнения.

# %%
long_phrase = 'Насколько проще было бы писать программы, если бы не заказчики'
short_phrase = '640Кб должно хватить для любых задач. Билл Гейтс (по легенде)'

# %%
if len(long_phrase)>len(short_phrase):
    print (True)
else:
    print (False)
# Out:
# True

# %% [markdown]
# **Задание 2**. Дано значение объема файла в байтах. Напишите перевод этого значения в мегабайты в формате: "*Объем файла равен 213.68Mb*"

# %%
# объем файла в байтах
file_bitesize = int(input("Введите объем файла в байтах: "))
# Расчет пошагово
file_kbsize = file_bitesize / 1024  # объем файла в килобайтах
file_mbsize = file_kbsize / 1024  # объем файла в мегабайтах
print ("Объем файла равен ", round(file_mbsize,2), "Mb", sep="")
# Out:
# Введите объем файла в байтах: 1222222222
# Объем файла равен 1165.6Mb

# %% [markdown]
# **Задание 3**. Разработать приложение для определения знака зодиака по дате рождения. Пример:
#
# Введите месяц: март
#
# Введите число: 6
#
# Вывод:
# Рыбы

# %% [markdown]
# ### Выполнение расчета выполняется исходя из следующих допущений:
# | # | Знак зодиака | Дата начала   | Дата начала |
# |-- |--------------|---------------|-------------|
# |♈| Овен	      |21 марта |	 20 апреля|
# |♉|Телец	   |21 апреля 	 |21 мая|
# |♊|Близнецы	  |22 мая 	| 21 июня|
# |♋|Рак	    |22 июня 	| 22 июля|
# |♌|Лев	    |23 июля 	| 21 августа|
# |♍|Дева	    |22 августа |	 23 сентября|
# |♎|Весы	    |24 сентября |	 23 октября|
# |♏|Скорпион	|24 октября |	 22 ноября|
# |♐|Стрелец	|23 ноября 	| 22 декабря|
# |♑|Козерог	|23 декабря |	 20 января|
# |♒|Водолей	|21 января 	| 19 февраля|
# |♓|Рыбы	    |20 февраля 	| 20 марта|

# %%
# для начала получим месяц:
birth_month_input = input("Введите месяц:") # переменная для получения значения месяца
birth_month = birth_month_input.upper() # оставляем возможность написания с большой буквы

# Теперь получим дату:
try:
    birth_date = int(input("Введите число:"))
    # Убираем несуществующие даты:
    # Дата больше 31
    if birth_date > 31:
        print ("Ошибка ввода данных")
    # Дата 29 и 30 февраля
    elif birth_month == "ФЕВРАЛЬ" and birth_date > 28:
        print ("Ошибка ввода данных")
    # Дата 30 апреля, июня, сентября и ноября
    elif birth_date == 31 and (birth_month == "АПРЕЛЬ" or \
                               birth_month == "ИЮНЬ" or \
                               birth_month == "СЕНТЯБРЬ" or \
                               birth_month == "НОЯБРЬ"):
        print ("Ошибка ввода данных")
    
    # После того, как убрали несуществующие даты, определяем знаки зодиака:        
    
    elif birth_month == "ЯНВАРЬ":
        # Козерог или Водолей    
        if birth_date < 21:
            print ("Козерог")
        else:
            print ("Водолей")

    elif birth_month == "ФЕВРАЛЬ":
        # Водолей или Рыбы    
        if birth_date <20:
            print ("Водолей")
        else:
            print ("Рыбы") 

    elif birth_month == "МАРТ":
        # Рыбы или Овен
        if birth_date < 21:
            print ("Рыбы")
        else:
            print ("Овен") 

    elif birth_month == "АПРЕЛЬ":
        # Овен или Телец
        if birth_date < 21:
            print ("Овен")
        else:
            print ("Телец")

    elif birth_month == "МАЙ":
        # Телец или Близнецы    
        if birth_date <22:
            print ("Телец")
        else:
            print ("Близнецы")

    elif birth_month == "ИЮНЬ":
        # Близнецы или Рак    
        if birth_date <22:
            print ("Близнецы")
        else:
            print ("Рак")       

    elif birth_month == "ИЮЛЬ":
        # Рак или Лев    
        if birth_date < 23:
            print ("Рак")
        else:
            print ("Лев")         

    elif birth_month == "АВГУСТ":
        # Лев или Дева    
        if birth_date < 22:
            print ("Лев")
        else:
            print ("Дева")          

    elif birth_month == "СЕНТЯБРЬ":
        # Дева или Весы    
        if birth_date <24:
            print ("Дева")
        else:
            print ("Весы")             

    elif birth_month == "ОКТЯБРЬ":
        # Весы или Скорпион    
        if birth_date < 24:
            print ("Весы")
        else:
            print ("Скорпион")          

    elif birth_month == "НОЯБРЬ":
        # Скорпион или Стрелец
        if birth_date < 23:
            print ("Скорпион")
        else:
            print ("Стрелец")        

    elif birth_month == "ДЕКАБРЬ":
        # Стрелец или Козерог    
        if birth_date < 23:
            print ("Стрелец")
        else:
            print ("Козерог")
    else:
        print ("Ошибка ввода данных")        


except (TypeError, ValueError):
    print ('Ошибка ввода данных')
# Out:
# Введите месяц:Январь
# Введите число:13
# Козерог

# %% [markdown]
# **Задание 4**. Нужно разработать приложение для финансового планирования.
# Приложение учитывает сколько уходит на ипотеку, "на жизнь" и сколько нужно отложить на пенсию.
# Пользователь вводит:
# - заработанную плату в месяц.
# - сколько процентов от ЗП уходит на ипотеку.
# - сколько процентов от ЗП уходит "на жизнь".
# - сколько раз приходит премия в год.
#
# Остальная часть заработанной платы откладывается на пенсию.
#
# Также пользователю приходит премия в размере зарплаты, от которой половина уходит на отпуск, а вторая половина откладывается.
#
# Программа должна учитывать сколько премий было в год.
#
# Нужно вывести сколько денег тратит пользователь на ипотеку и сколько он накопит за год.
#
# Пример:
#
# Введите заработанную плату в месяц: 100000
#
# Введите сколько процентов уходит на ипотеку: 30
#
# Введите сколько процентов уходит на жизнь: 50
#
# Введите количество премий за год: 2
#
# Вывод:
# На ипотеку было потрачено: 360000 рублей
# Было накоплено: 340000 рублей

# %%
# Вводим исходные показатели, с проверкой на внесение чисел:
try:
    zar_plata_month = int(input("Введите заработанную плату в месяц:"))
    ipoteka_month = int(input("Введите сколько процентов уходит на ипотеку:"))
    life_month = int(input("Введите сколько процентов уходит на жизнь:"))
    premii_count = int(input("Введите количество премий за год:"))

    # Проверяем правильность заполнения процентов:
    if ipoteka_month + life_month > 100:
        print ("Ошибка в заполнении процентов: больше 100%")
    else:
        # Рассчитываем годовые доходы:
        zar_plata_year = zar_plata_month * 12 # заработная плата за год
        premii_year = zar_plata_month * premii_count # годовая премия
        inflow_year = zar_plata_year + premii_year

        # Рассчитываем годовые расходы:
        ipoteka_year = zar_plata_year * ipoteka_month / 100 # годовые расходы на ипотеку 
        life_year = zar_plata_year * life_month / 100 # годовые расходы на жизнь
        rest_year = premii_year / 2 # годовые расходы на отпуск
        flow_year = ipoteka_year + life_year + rest_year

        # Рассчитываем итоговый баланс:
        balance = inflow_year - flow_year
        # Выводим результат:
        print ("На ипотеку было потрачено: ", int(ipoteka_year),sep="") # добавил перевод строки, для красоты
        print ("Было накоплено: ", int(balance),sep="")
        
except (TypeError, ValueError):
    print ('Ошибка ввода данных')
# Out:
# Введите заработанную плату в месяц:120000
# Введите сколько процентов уходит на ипотеку:10%
# Ошибка ввода данных
