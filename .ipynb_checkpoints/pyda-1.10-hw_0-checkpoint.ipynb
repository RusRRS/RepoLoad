# %%
#Импорт библиотек
from pylab import rcParams
# импортируем нужные библиотеки
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('F:\Program\git_base\GitHub\MyRepo\PYDA_10\Video_Games_Sales_as_at_22_Dec_2016.csv')
df.head(15)
# df[df['Publisher'] == 'Microsoft Game Studios'].head(15)
# Out:
#                            Name Platform  Year_of_Release         Genre  \
# 0                    Wii Sports      Wii           2006.0        Sports
# 1             Super Mario Bros.      NES           1985.0      Platform
# 2                Mario Kart Wii      Wii           2008.0        Racing
# 3             Wii Sports Resort      Wii           2009.0        Sports
# 4      Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# 5                        Tetris       GB           1989.0        Puzzle
# 6         New Super Mario Bros.       DS           2006.0      Platform
# 7                      Wii Play      Wii           2006.0          Misc
# 8     New Super Mario Bros. Wii      Wii           2009.0      Platform
# 9                     Duck Hunt      NES           1984.0       Shooter
# 10                   Nintendogs       DS           2005.0    Simulation
# 11                Mario Kart DS       DS           2005.0        Racing
# ...

# %%
# Сформируем датафрейм по нинтендо и плэйстейшн
publisher_dynamics = df[df['Platform'].str.contains('ps', case=False) |  df['Publisher'].str.contains('Nintendo', case=False)]
# Построим столбчатую диаграмму сравнение количества продаж в 2000 и 2010 году Ниндендо и МС.
publisher_dynamics
# Out:
#                                                     Name Platform  \
# 0                                             Wii Sports      Wii
# 1                                      Super Mario Bros.      NES
# 2                                         Mario Kart Wii      Wii
# 3                                      Wii Sports Resort      Wii
# 4                               Pokemon Red/Pokemon Blue       GB
# 5                                                 Tetris       GB
# 6                                  New Super Mario Bros.       DS
# 7                                               Wii Play      Wii
# 8                              New Super Mario Bros. Wii      Wii
# 9                                              Duck Hunt      NES
# 10                                            Nintendogs       DS
# 11                                         Mario Kart DS       DS
# 12                           Pokemon Gold/Pokemon Silver       GB
# ...

# %%
publisher_dynamics = df[df['Publisher'].str.contains('Sony Computer Entertainment', case=False) |  df['Publisher'].str.contains('Nintendo', case=False)]

# %%
publisher_dynamics
# Out:
#                                                     Name Platform  \
# 0                                             Wii Sports      Wii
# 1                                      Super Mario Bros.      NES
# 2                                         Mario Kart Wii      Wii
# 3                                      Wii Sports Resort      Wii
# 4                               Pokemon Red/Pokemon Blue       GB
# 5                                                 Tetris       GB
# 6                                  New Super Mario Bros.       DS
# 7                                               Wii Play      Wii
# 8                              New Super Mario Bros. Wii      Wii
# 9                                              Duck Hunt      NES
# 10                                            Nintendogs       DS
# 11                                         Mario Kart DS       DS
# 12                           Pokemon Gold/Pokemon Silver       GB
# ...

# %%
plt.plot(df['Year_of_Release'],df['User_Count'])

# %%
plt.scatter(df['Critic_Score'],df['EU_Sales'])

# %%
plt.bar(df['Year_of_Release'],df['EU_Sales'])
# Out:
# <Container object of 16719 artists>

# %%
plt.hist(df['Platform'])
# Out:
# (array([ 656., 2302., 1407.,  418.,  987., 4689., 2034.,  418., 1328.,
#         2480.]),
#  array([ 0.,  3.,  6.,  9., 12., 15., 18., 21., 24., 27., 30.]),
#  <a list of 10 Patch objects>)

# %%
df1 = df[[x for x in df.columns if 'Sales' in x] + ['Year_of_Release']]\
    .groupby('Year_of_Release').sum()
df1.head()
# Out:
#                  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Year_of_Release
# 1980.0              10.59      0.67      0.00         0.12         11.38
# 1981.0              33.40      1.96      0.00         0.32         35.77
# 1982.0              26.92      1.65      0.00         0.31         28.86
# 1983.0               7.76      0.80      8.10         0.14         16.79
# 1984.0              33.28      2.10     14.27         0.70         50.36

# %%
df1.plot()

# %%
# Агрегируем количество имен по годам и по полу
publisher_dynamics_2 = publisher_dynamics.groupby(['Publisher', 'Year_of_Release']).sum()
# gender_dynamics
# publisher_dynamics_2.unstack('Publisher').plot()

# %%
publisher_dynamics_2

# %%
publisher_dynamics_2.unstack().plot(kind='bar')

# %%
# Столбчатая диаграмма 
plt.barh(names_all['Gender'], names_all['Count'])

# %%
plt.bar(names_all['Gender'], names_all['Count'])

# %%
# Агрегируем количество имен по годам и по полу
gender_dynamics = names_all.groupby([names_all.index, 'Gender']).sum()
# gender_dynamics
gender_dynamics.unstack('Gender').plot()

# %%
import seaborn as sns

# %%
sns_plot = sns.pairplot(
    df[['Global_Sales', 'Critic_Score', 'User_Score']])
sns_plot
