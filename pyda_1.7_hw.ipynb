# %%
import pandas as pd

# %% [markdown]
# ##### Задание 1
# Напишите функцию, которая классифицирует фильмы из материалов занятия по следующим правилам:
# 	- оценка 2 и меньше - низкий рейтинг
# 	- оценка 4 и меньше - средний рейтинг
# 	- оценка 4.5 и 5 - высокий рейтинг
#
# Результат классификации запишите в столбец *class*

# %%
ratings_df = pd.read_csv('F:\\Program\\git_base\\GitHub\\MyRepo\\PYDA_07\\ml-latest-small\\ratings.csv', \
                         sep=',', header=0, encoding='UTF-8')
movie_df = pd.read_csv('F:\\Program\\git_base\\GitHub\\MyRepo\\PYDA_07\\ml-latest-small\\movies.csv', \
                         sep=',', header=0, encoding='UTF-8')
joined_df = movie_df.merge(ratings_df, on='movieId', how='left')

# %%
joined_df.head()
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    userId  rating     timestamp
# 0     7.0     3.0  8.518667e+08
# 1     9.0     4.0  9.386292e+08
# 2    13.0     5.0  1.331380e+09
# 3    15.0     2.0  9.979383e+08
# 4    19.0     3.0  8.551901e+08

# %%
def class_name(a):
    """определяем класс по рейтингу"""
    if a >= 4.5:
        return "Высокий рейтинг"
    elif a > 2.0:
        return "Средний рейтинг"
    elif a <= 2.0:
        return "Низкий рейтинг"
    else:
        return "Нет данных по рейтингу"

# %%
joined_df['class'] = joined_df['rating'].apply(class_name)
joined_df.head()
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    userId  rating     timestamp            class
# 0     7.0     3.0  8.518667e+08  Средний рейтинг
# 1     9.0     4.0  9.386292e+08  Средний рейтинг
# 2    13.0     5.0  1.331380e+09  Высокий рейтинг
# 3    15.0     2.0  9.979383e+08   Низкий рейтинг
# 4    19.0     3.0  8.551901e+08  Средний рейтинг

# %% [markdown]
# ##### Задание 4
# Есть мнение, что *"раньше снимали настоящее кино, не то что сейчас"*.
# Ваша задача проверить это утверждение, используя файлы с рейтингами фильмов из материалов занятия.
# Т. е. проверить верно ли, что с ростом года выпуска фильма его средний рейтинг становится ниже.
#
# При этом мы не будем затрагивать субьективные факторы выставления этих рейтингов, а пройдемся по следующему алгоритму:
# 1. В переменную **years** запишите список из всех годов с **1950 по 2010**.
# 2. Напишите функцию **production_year**, которая каждой строке из названия фильма выставляет год выпуска.
#
# Не все названия фильмов содержат год выпуска в одинаковом формате, поэтому используйте следующий алгоритм:
# 	- для каждой строки пройдите по всем годам списка years
# 	- если номер года присутствует в названии фильма, то функция возвращает этот год как год выпуска
# 	- если ни один из номеров года списка years не встретился в названии фильма, то возвращается 1900 год
#
# 3. Запишите год выпуска фильма по алгоритму пункта 2 в новый столбец **'year'**
# 4. Посчитайте средний рейтинг всех фильмов для каждого значения столбца **'year'** и отсортируйте результат по убыванию   рейтинга

# %%
joined_df.head()
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    userId  rating     timestamp            class
# 0     7.0     3.0  8.518667e+08  Средний рейтинг
# 1     9.0     4.0  9.386292e+08  Средний рейтинг
# 2    13.0     5.0  1.331380e+09  Высокий рейтинг
# 3    15.0     2.0  9.979383e+08   Низкий рейтинг
# 4    19.0     3.0  8.551901e+08  Средний рейтинг

# %%
joined_df_4 = joined_df

# %%
joined_df_4.head()
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    userId  rating     timestamp            class
# 0     7.0     3.0  8.518667e+08  Средний рейтинг
# 1     9.0     4.0  9.386292e+08  Средний рейтинг
# 2    13.0     5.0  1.331380e+09  Высокий рейтинг
# 3    15.0     2.0  9.979383e+08   Низкий рейтинг
# 4    19.0     3.0  8.551901e+08  Средний рейтинг

# %%
years = []
for element in range(1950, 2011):
    years.append(element)

# %%
def production_year (a):
    list_text = a.title.split('(')

# %%
def production_year (a):
    list_text = a.title.split('(')
    for word in list_text:
        if word == '1995)':
            return int(word.replace(")", ""))
    return False

joined_df_4['production_year'] = joined_df_4.apply(production_year, axis=1)
joined_df_4['production_yearX2'] = joined_df_4['production_year'] * 2
joined_df_4.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-564-5e8b33dd148c> in <module>()
#       9     return False
#      10
# ---> 11 joined_df_4['production_year'] = joined_df_4.apply(production_year, axis=1)
#      12
#      13 joined_df_4.head()
#
# F:\Python\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, broadcast, raw, reduce, args, **kwds)
#    4875                         f, axis,
#    4876                         reduce=reduce,
# -> 4877                         ignore_failures=ignore_failures)
#    4878             else:
#    4879                 return self._apply_broadcast(f, axis)
#
# F:\Python\lib\site-packages\pandas\core\frame.py in _apply_standard(self, func, axis, ignore_failures, reduce)
#    4971             try:
#    4972                 for i, v in enumerate(series_gen):
# -> 4973                     results[i] = func(v)
# ...

# %%
def year_in_years (a):
    companies = years
    if a['production_year'] in companies:
        return a['production_year']
    return 1990

joined_df_4['production_year'] = joined_df_4.apply(year_in_years, axis=1)

#     for year_element in years:
#         for element in joined['production_year']
#         if joined['production_year']
#     if 

joined_df_4
# Out:
#         movieId                                              title  \
# 0             1                                   Toy Story (1995)
# 1             1                                   Toy Story (1995)
# 2             1                                   Toy Story (1995)
# 3             1                                   Toy Story (1995)
# 4             1                                   Toy Story (1995)
# 5             1                                   Toy Story (1995)
# 6             1                                   Toy Story (1995)
# 7             1                                   Toy Story (1995)
# 8             1                                   Toy Story (1995)
# 9             1                                   Toy Story (1995)
# 10            1                                   Toy Story (1995)
# 11            1                                   Toy Story (1995)
# 12            1                                   Toy Story (1995)
# ...

# %%
# joined['title2'] = joined.apply(production_year, axis=1)
# joined{.head()}
joined[joined.index == 99912]
# Out:
#        movieId       title              genres  userId  rating     timestamp  \
# 99912   143410  Hyena Road  (no genres listed)   624.0     2.0  1.474225e+09
#
#                 class
# 99912  Низкий рейтинг

# %%
joined_99912 = joined[joined.index == 99911]

# %%
joined_99912['title']
# Out:
# 99911    Bridge of Spies (2015)
# Name: title, dtype: object

# %%
s2 = []
s.append(joined_99912['title'].str.split('('))
for element in s:
    s2.append(element) 
s2
# Out:
# [99911    [Bridge of Spies , 2015)]
#  Name: title, dtype: object, 99911    [Bridge of Spies , 2015)]
#  Name: title, dtype: object]

# %%
f = lambda x:"(".join(x for x in x.split() if x not in freq)
joined['title'] = joined['title'].apply(f)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-155-d5868a41ca24> in <module>()
#       1 f = lambda x:"(".join(x for x in x.split() if x not in freq)
# ----> 2 joined['title'] = joined['title'].apply(f)
#
# F:\Python\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    2549             else:
#    2550                 values = self.asobject
# -> 2551                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    2552
#    2553         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src/inference.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-155-d5868a41ca24> in <lambda>(x)
# ----> 1 f = lambda x:"(".join(x for x in x.split() if x not in freq)
#       2 joined['title'] = joined['title'].apply(f)
#
# <ipython-input-155-d5868a41ca24> in <genexpr>(.0)
# ...
